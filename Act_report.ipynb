# %% [markdown]
# ## Project Introduction
# In this project we were supposed to get twitter data on dog ratings.
# We were given 3 different datasets to clean and come up with the findings.
# Users usually tweets about their dogs and rate them under dog ratings hash tag

# %% [markdown]
# ![image.png](attachment:image.png)
# We can see that in 2015 there was more tweets in a day and seems number of tweets per day are reducing with time. This shows that people are not rating their dogs over time

# %% [markdown]
# ![image.png](attachment:image.png)
# There were many users who are using Iphone while using twittwer to rate their dogs compared to other device types. This can mean that most users whpo rare dogs are the high class users compared to low class who can not afford the iphones

# %% [markdown]
# ![image.png](attachment:image.png)
# After  `Pupper` dog types were tweeted more than the others and `Floofer` type was least tweeted. This can mean that more people have `Pupper` dog types compared with others or Pupper dog types is the best breed to rare.

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# We can see that `Puppo` was retweeted most followed by `doggo`. This can mean that twitter users were impressed with the dog rating or the caption text with the dog ratings

# %% [markdown]
# ![image.png](attachment:image.png)
# Also `Puppo` dog type had most likes after the ratings which means that people liked most this type of dogs

# %% [markdown]
# ### Conclusion
# With this report we found out the following conculusions
# 1. Puppo is the most liked dog type
# 2. Dog are rared by the high class people
# 3. Pupper is the most rated dog type
# 4. Most rating tweets per day was done before 2015
